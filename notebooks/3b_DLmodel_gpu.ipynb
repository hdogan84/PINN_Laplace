# %%
import numpy as np # linear algebra 
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

# %%
#current_folder = Path().resolve()
import sys
from pathlib import Path

# Get the parent folder (one level up)
parent_folder = Path().resolve().parent
src_path = parent_folder / 'src'
sys.path.append(str(src_path))

from tools.grad_calc import grad_x, grad_y, TotalLoss2

# %%
dataset_name = "2D_Laplc/"

#Configurpave to be dynamically adjusted
download_path = "../data/" #In the .gitignore list an

#n the rest of the code.
path_to_datasets = download_path + "/" + dataset_name

# %%
# This cell now makes use of the downloadfolder for the datasets.
df_train= pd.read_csv(path_to_datasets + "/" + 'laplc_train.csv')
df_test=pd.read_csv(path_to_datasets + "/" +  'laplc_test.csv')
#print("Dataframes MITBIH correctly read into workspace")

#split target and value
train_target=df_train['p(x,y)']
test_target=df_test['p(x,y)']
train=df_train.drop('p(x,y)',axis=1)
test=df_test.drop('p(x,y)',axis=1)

# %%
lenX = int(np.sqrt(len(df_train)))
lenY = lenX
batch_size = lenX * lenY
lambdaDBC = 1000 #Weight factor for the Dirichlet loss. 
kappa = 0

# %% [markdown]
# ## **Artificial Neural Network**

# %% [markdown]
# Implement Torch Dataset object

# %%
class PDE_Dataset(Dataset):
    def __init__(self, csv_file, transform=None, target_transform=None):
        self.dataframe = csv_file.values
        self.transform = transform
        self.target_transform = target_transform

    def __len__(self):
        return len(self.dataframe)
        #return self.dataframe.shape[0] # Alternative notation

    def __getitem__(self, idx):
        inputs = torch.tensor(self.dataframe[idx,:-1], requires_grad=True).to(torch.float32)
        label = torch.tensor(self.dataframe[idx,-1]).to(torch.float32)

        return inputs, label

# %% [markdown]
# Custom function for preprocessing (to elaborate later, currently just returns the input itself)

# %%
class Lambda(nn.Module):
    def __init__(self, func):
        super().__init__()
        self.func = func

    def forward(self, x):
        return self.func(x)


def preprocess(x):
    return x * torch.Tensor([1.0])

# %%
# Define the ANN model
class SimpleANN(nn.Module):
    def __init__(self, input_size, output_size):
        super().__init__()
        self.fc0 = nn.Sequential(Lambda(preprocess))
        self.fc1 = nn.Linear(input_size, 24)
        self.fc2 = nn.Linear(24, 48)  
        self.fc3 = nn.Linear(48, 24) 
        self.fc4 = nn.Linear(24, 12)  
        self.fc5 = nn.Linear(12, output_size)  # Hidden to output layer
        self.fc6 = nn.Linear(6, output_size)  # Hidden to output layer
        self.relu = nn.LeakyReLU(negative_slope=0.001)    # Activation function
        self.dropout = nn.Dropout(p=0.1)
        self.sigmoid = nn.Sigmoid() 

    def forward(self, x):
        #x = self.fc0(x)
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        x = self.relu(x)
        x = self.fc3(x)
        x = self.relu(x)
        x = self.fc4(x)
        x = self.relu(x)
        x = self.fc5(x)
        return x

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda:0

# %%
print(f"Is CUDA available? {torch.cuda.is_available()}")
print(f"Current device: {torch.cuda.current_device()}")
print(f"Device name: {torch.cuda.get_device_name(torch.cuda.current_device())}")
# Out:
# Is CUDA available? True
# Current device: 0
# Device name: NVIDIA GeForce RTX 3060 Laptop GPU

# %%
def target_func(x,y): 
    pres = x*x - y*y
    return pres

# %%
class DirichletBC(nn.Module):
    def __init__(self):
        super(DirichletBC, self).__init__()

    def forward(self, inputs, target_func, kappa):
        """
        Impose Dirichlet BC on the boundary.
        Args:
        Returns:
            torch.Tensor: Computed loss (scalar).
        """
        DirichletValues = []
        DirichletIndex = []

        for i, (x,y) in enumerate(inputs):
            if x==0 or x==1 or y==0 or y==1:
                DirichletValues.append(target_func(inputs[i,0], inputs[i,1]))
                DirichletIndex.append(i)
        
        DirichletValues = torch.tensor(DirichletValues,requires_grad=True)
        DirichletIndex = torch.tensor(DirichletIndex,requires_grad=False)
                   
        return DirichletIndex.unsqueeze(1), DirichletValues.unsqueeze(1)

# %%
def get_data(train_ds, valid_ds, bs, shuffle):
    return (
        DataLoader(train_ds, batch_size=bs, shuffle=shuffle),
        DataLoader(valid_ds, batch_size=bs),
    )

# %%
train_ds = PDE_Dataset(df_train)
test_ds = PDE_Dataset(df_test)
train_dl, test_dl = get_data(train_ds, test_ds, batch_size, shuffle=False)

# %% [markdown]
# Apply Boundary Conditions

# %%
bc = DirichletBC()

for inputs, labels in train_dl:
    # Watch out here. This calculated assuming one batch size=dataset_len
        
    DirichletIndx, DirichletVals = bc(inputs,target_func, kappa)

# %%
mse_loss = nn.MSELoss()

# %%
def batch_loss_train(outputs, labels, len_x, len_y, loss_fn, optimizer):
    
    loss = loss_fn(outputs, labels, len_x, len_y) #This is Laplace loss

    loss.backward()
    
    optimizer.step()
    optimizer.zero_grad()

    return loss.item()

# %%
def batch_loss_test(outputs, labels, loss_fn):
    loss = loss_fn(outputs, labels)    
    return loss.item()

# %%
def test_loop(dataloader, model, loss_fn, print_every, epoch):
    # Set the model to evaluation mode - important for batch normalization and dropout layers
    model.eval()
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, mse, mape = 0, 0, 0
    epsilon = 1e-8
    #global best_rel_abs_error

    # Evaluating the model with torch.no_grad()    
    with torch.no_grad():
        for X, y in dataloader:
            
            X, y = X.to(device), y.to(device)

            pred = model(X)
            pred = pred.reshape(len(y)) 
            
            mse += torch.sum((y - pred) ** 2).item()
            #y = y + epsilon 
            mape += torch.abs((y - pred)/y)

    finite_mask = torch.isfinite(mape)
    # Filter out inf values, i.e. avoid zero-division
    mape = torch.mean(mape[finite_mask])
    
    # Keep track of best value for Mean Rel. Abs. Error
    error_tracker.update(mape)

    if epoch % print_every == 0:
       print(f"Test set => Mean Squared error: {(100*mse/size):>0.6f}, Mean Rel. Abs error: {(mape):>8f} \n")

# %%
def train_loop(dataloader, model, loss_fn, optimizer, print_every, epoch):
    model.train()
    optimizer.zero_grad()
    train_loss = 0.0
    
    for inputs, labels in dataloader:
        # forward pass. Better without shuffle to keep the coordinates sorted
        
        inputs, labels = inputs.to(device), labels.to(device)
        
        outputs = model(inputs)
        #print(outputs.view(lenX,lenX))

        train_loss += batch_loss_train(outputs,labels,lenX,lenY,loss_fn, optimizer)
    
    if epoch % print_every == 0:
        print(f"Epoch {epoch+1}   -------------------------------")
        print(f'Train loss: {train_loss}')

# %%
class TotalLoss(nn.Module):
    def __init__(self):
        super(TotalLoss, self).__init__()

    def forward(self, preds, targets, len_x, len_y):
        """
        Compute the Calculate the Laplace eq. for predictions.
        labels (targets) loss should satisfy zero on the boundary
        """
                            
        gradp_x = grad_x(preds,len_x)
        gradp_y = grad_y(preds,len_y)

        grad_p_xx = grad_x(gradp_x,len_x)
        grad_p_yy = grad_y(gradp_y,len_y)

        laplacian = grad_p_xx + grad_p_yy 
        PDELoss = mse_loss(laplacian, torch.zeros_like(laplacian))

        # Dirichlet BC loss
        DBCpreds = preds[DirichletIndx.squeeze(1)].clone()
        DBCLoss = mse_loss(DBCpreds, DirichletVals)
        
        #print(f"PDE loss: {PDELoss}, DBC loss: {DBCLoss}")
        loss = PDELoss.sum() + lambdaDBC * DBCLoss.sum()
        
        return loss

# %%
def fit(epochs, model, loss_fn, opt, train_dl, valid_dl):
    print_every = 1
    for epoch in range(epochs):  
        train_loop(train_dl, model, loss_fn, optimizer, print_every, epoch)
        test_loop(train_dl, model, loss_fn, print_every, epoch)

# %%
# Define the model
torch.set_printoptions(precision=6)

input_size = 2  # Number of input features
output_size = 1  # Output size (e.g., regression or binary classification)
model = SimpleANN(input_size, output_size).to(device)
lenX = torch.tensor(lenX).to(device)
lenY = torch.tensor(lenY).to(device)
DirichletIndx = DirichletIndx.to(device)
DirichletVals = DirichletVals.to(device)

# Define loss and optimizer
#criterion =  TotalLoss2(DirichletIndx, DirichletVals, lambdaDBC)
criterion =  TotalLoss()

# %%
class ErrorTracker:
    def __init__(self):
        self.best_rel_abs_error = float('inf')

    def update(self, current_error):
        if current_error < self.best_rel_abs_error:
            self.best_rel_abs_error = current_error
            #print(f"New Best Rel Abs Error: {self.best_rel_abs_error:.6f}")

# Use for best Mean Rel. Abs Error
error_tracker = ErrorTracker()

# %%
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
fit(200, model, criterion, optimizer, train_dl, test_dl)
# Out:
# Epoch 1   -------------------------------
# Train loss: 5.502440452575684
# Test set => Mean Squared error: 0.094286, Mean Rel. Abs error: 0.363069
#
# Epoch 2   -------------------------------
# Train loss: 5.4680047035217285
# Test set => Mean Squared error: 0.092526, Mean Rel. Abs error: 0.360956
#
# Epoch 3   -------------------------------
# Train loss: 5.451193809509277
# Test set => Mean Squared error: 0.094120, Mean Rel. Abs error: 0.359676
#
# Epoch 4   -------------------------------
# Train loss: 5.430019378662109
# Test set => Mean Squared error: 0.097553, Mean Rel. Abs error: 0.358671
#
# Epoch 5   -------------------------------
# Train loss: 5.4128594398498535
# Test set => Mean Squared error: 0.099136, Mean Rel. Abs error: 0.357634
#
# Epoch 6   -------------------------------
# Train loss: 5.393342018127441
# Test set => Mean Squared error: 0.096314, Mean Rel. Abs error: 0.355508
#
# Epoch 7   -------------------------------
# Train loss: 5.380919456481934
# Test set => Mean Squared error: 0.093300, Mean Rel. Abs error: 0.352754
#
# Epoch 8   -------------------------------
# Train loss: 5.359428405761719
# Test set => Mean Squared error: 0.093019, Mean Rel. Abs error: 0.350327
#
# Epoch 9   -------------------------------
# Train loss: 5.34080171585083
# Test set => Mean Squared error: 0.094500, Mean Rel. Abs error: 0.348457
#
# Epoch 10   -------------------------------
# Train loss: 5.330082416534424
# Test set => Mean Squared error: 0.092131, Mean Rel. Abs error: 0.345789
#
# Epoch 11   -------------------------------
# Train loss: 5.313785076141357
# Test set => Mean Squared error: 0.088571, Mean Rel. Abs error: 0.343123
#
# Epoch 12   -------------------------------
# Train loss: 5.291706085205078
# Test set => Mean Squared error: 0.087007, Mean Rel. Abs error: 0.341171
#
# Epoch 13   -------------------------------
# Train loss: 5.281761646270752
# Test set => Mean Squared error: 0.086583, Mean Rel. Abs error: 0.339550
#
# Epoch 14   -------------------------------
# Train loss: 5.2606201171875
# Test set => Mean Squared error: 0.087914, Mean Rel. Abs error: 0.338532
#
# Epoch 15   -------------------------------
# Train loss: 5.2423224449157715
# Test set => Mean Squared error: 0.087101, Mean Rel. Abs error: 0.336900
#
# Epoch 16   -------------------------------
# Train loss: 5.231784343719482
# Test set => Mean Squared error: 0.085173, Mean Rel. Abs error: 0.335132
#
# Epoch 17   -------------------------------
# Train loss: 5.213743209838867
# Test set => Mean Squared error: 0.082166, Mean Rel. Abs error: 0.332742
#
# Epoch 18   -------------------------------
# Train loss: 5.199887275695801
# Test set => Mean Squared error: 0.081566, Mean Rel. Abs error: 0.331239
#
# Epoch 19   -------------------------------
# Train loss: 5.185037612915039
# Test set => Mean Squared error: 0.080996, Mean Rel. Abs error: 0.329679
#
# Epoch 20   -------------------------------
# Train loss: 5.170029163360596
# Test set => Mean Squared error: 0.078826, Mean Rel. Abs error: 0.327842
#
# Epoch 21   -------------------------------
# Train loss: 5.158330917358398
# Test set => Mean Squared error: 0.079473, Mean Rel. Abs error: 0.327410
#
# Epoch 22   -------------------------------
# Train loss: 5.143697738647461
# Test set => Mean Squared error: 0.080869, Mean Rel. Abs error: 0.326879
#
# Epoch 23   -------------------------------
# Train loss: 5.125906944274902
# Test set => Mean Squared error: 0.080550, Mean Rel. Abs error: 0.325488
#
# Epoch 24   -------------------------------
# Train loss: 5.103649139404297
# Test set => Mean Squared error: 0.080102, Mean Rel. Abs error: 0.324394
#
# Epoch 25   -------------------------------
# Train loss: 5.088382720947266
# Test set => Mean Squared error: 0.079116, Mean Rel. Abs error: 0.323409
#
# Epoch 26   -------------------------------
# Train loss: 5.074443340301514
# Test set => Mean Squared error: 0.076462, Mean Rel. Abs error: 0.322071
#
# Epoch 27   -------------------------------
# Train loss: 5.061513423919678
# Test set => Mean Squared error: 0.074612, Mean Rel. Abs error: 0.321326
#
# Epoch 28   -------------------------------
# Train loss: 5.052184581756592
# Test set => Mean Squared error: 0.075840, Mean Rel. Abs error: 0.321693
#
# Epoch 29   -------------------------------
# Train loss: 5.0359368324279785
# Test set => Mean Squared error: 0.077627, Mean Rel. Abs error: 0.322096
#
# Epoch 30   -------------------------------
# Train loss: 5.023519515991211
# Test set => Mean Squared error: 0.076116, Mean Rel. Abs error: 0.321248
#
# Epoch 31   -------------------------------
# Train loss: 5.005965709686279
# Test set => Mean Squared error: 0.072736, Mean Rel. Abs error: 0.319481
#
# Epoch 32   -------------------------------
# Train loss: 4.991669654846191
# Test set => Mean Squared error: 0.071916, Mean Rel. Abs error: 0.318773
#
# Epoch 33   -------------------------------
# Train loss: 4.979729652404785
# Test set => Mean Squared error: 0.073290, Mean Rel. Abs error: 0.318685
#
# Epoch 34   -------------------------------
# Train loss: 4.968598365783691
# Test set => Mean Squared error: 0.072443, Mean Rel. Abs error: 0.317150
#
# Epoch 35   -------------------------------
# Train loss: 4.954892158508301
# Test set => Mean Squared error: 0.071086, Mean Rel. Abs error: 0.315376
#
# Epoch 36   -------------------------------
# Train loss: 4.943192005157471
# Test set => Mean Squared error: 0.071336, Mean Rel. Abs error: 0.314720
#
# Epoch 37   -------------------------------
# Train loss: 4.932707786560059
# Test set => Mean Squared error: 0.071064, Mean Rel. Abs error: 0.313779
#
# Epoch 38   -------------------------------
# Train loss: 4.918863773345947
# Test set => Mean Squared error: 0.069337, Mean Rel. Abs error: 0.311792
#
# Epoch 39   -------------------------------
# Train loss: 4.907276153564453
# Test set => Mean Squared error: 0.067711, Mean Rel. Abs error: 0.309610
#
# Epoch 40   -------------------------------
# Train loss: 4.901180267333984
# Test set => Mean Squared error: 0.068477, Mean Rel. Abs error: 0.308793
#
# Epoch 41   -------------------------------
# Train loss: 4.887506484985352
# Test set => Mean Squared error: 0.070282, Mean Rel. Abs error: 0.308872
#
# Epoch 42   -------------------------------
# Train loss: 4.876828670501709
# Test set => Mean Squared error: 0.070105, Mean Rel. Abs error: 0.308433
#
# Epoch 43   -------------------------------
# Train loss: 4.8634796142578125
# Test set => Mean Squared error: 0.066047, Mean Rel. Abs error: 0.305963
#
# Epoch 44   -------------------------------
# Train loss: 4.856678485870361
# Test set => Mean Squared error: 0.065593, Mean Rel. Abs error: 0.304506
#
# Epoch 45   -------------------------------
# Train loss: 4.8373517990112305
# Test set => Mean Squared error: 0.067757, Mean Rel. Abs error: 0.304117
#
# Epoch 46   -------------------------------
# Train loss: 4.829319953918457
# Test set => Mean Squared error: 0.068363, Mean Rel. Abs error: 0.303348
#
# Epoch 47   -------------------------------
# Train loss: 4.815768718719482
# Test set => Mean Squared error: 0.065842, Mean Rel. Abs error: 0.301527
#
# Epoch 48   -------------------------------
# Train loss: 4.804086685180664
# Test set => Mean Squared error: 0.062865, Mean Rel. Abs error: 0.299625
#
# Epoch 49   -------------------------------
# Train loss: 4.794411659240723
# Test set => Mean Squared error: 0.062712, Mean Rel. Abs error: 0.298580
#
# Epoch 50   -------------------------------
# Train loss: 4.780989170074463
# Test set => Mean Squared error: 0.064601, Mean Rel. Abs error: 0.298657
#
# Epoch 51   -------------------------------
# Train loss: 4.777275085449219
# Test set => Mean Squared error: 0.063065, Mean Rel. Abs error: 0.296981
#
# Epoch 52   -------------------------------
# Train loss: 4.76678991317749
# Test set => Mean Squared error: 0.060499, Mean Rel. Abs error: 0.294756
#
# Epoch 53   -------------------------------
# Train loss: 4.7609968185424805
# Test set => Mean Squared error: 0.061954, Mean Rel. Abs error: 0.294720
#
# Epoch 54   -------------------------------
# Train loss: 4.742539882659912
# Test set => Mean Squared error: 0.064195, Mean Rel. Abs error: 0.294993
#
# Epoch 55   -------------------------------
# Train loss: 4.7403764724731445
# Test set => Mean Squared error: 0.062958, Mean Rel. Abs error: 0.293575
#
# Epoch 56   -------------------------------
# Train loss: 4.725527763366699
# Test set => Mean Squared error: 0.061359, Mean Rel. Abs error: 0.292536
#
# Epoch 57   -------------------------------
# Train loss: 4.7181291580200195
# Test set => Mean Squared error: 0.060552, Mean Rel. Abs error: 0.292070
#
# Epoch 58   -------------------------------
# Train loss: 4.700413227081299
# Test set => Mean Squared error: 0.059739, Mean Rel. Abs error: 0.291348
#
# Epoch 59   -------------------------------
# Train loss: 4.698571681976318
# Test set => Mean Squared error: 0.059252, Mean Rel. Abs error: 0.290446
#
# Epoch 60   -------------------------------
# Train loss: 4.685476303100586
# Test set => Mean Squared error: 0.060502, Mean Rel. Abs error: 0.290522
#
# Epoch 61   -------------------------------
# Train loss: 4.678773880004883
# Test set => Mean Squared error: 0.060158, Mean Rel. Abs error: 0.289855
#
# Epoch 62   -------------------------------
# Train loss: 4.667675971984863
# Test set => Mean Squared error: 0.058008, Mean Rel. Abs error: 0.287984
#
# Epoch 63   -------------------------------
# Train loss: 4.6537184715271
# Test set => Mean Squared error: 0.057606, Mean Rel. Abs error: 0.286960
#
# Epoch 64   -------------------------------
# Train loss: 4.651612281799316
# Test set => Mean Squared error: 0.058776, Mean Rel. Abs error: 0.287263
#
# Epoch 65   -------------------------------
# Train loss: 4.6404242515563965
# Test set => Mean Squared error: 0.057642, Mean Rel. Abs error: 0.286497
#
# Epoch 66   -------------------------------
# Train loss: 4.63092565536499
# Test set => Mean Squared error: 0.056343, Mean Rel. Abs error: 0.285604
#
# Epoch 67   -------------------------------
# Train loss: 4.623240947723389
# Test set => Mean Squared error: 0.057491, Mean Rel. Abs error: 0.285672
#
# Epoch 68   -------------------------------
# Train loss: 4.615562438964844
# Test set => Mean Squared error: 0.057903, Mean Rel. Abs error: 0.284729
#
# Epoch 69   -------------------------------
# Train loss: 4.604757308959961
# Test set => Mean Squared error: 0.055997, Mean Rel. Abs error: 0.283058
#
# Epoch 70   -------------------------------
# Train loss: 4.598159313201904
# Test set => Mean Squared error: 0.056192, Mean Rel. Abs error: 0.283034

# %%
print(f"Best Mean Rel. Abs. Error: {error_tracker.best_rel_abs_error:.5f}")
# Out:
# Best Mean Rel. Abs. Error: 0.36579

# %% [markdown]
# Inference

# %%
with torch.no_grad():
    for X, y in train_dl:
        X, y = X.to(device), y.to(device)
        pred = model(X)
        pred = pred.reshape(len(y)) 
        labels = y

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Create a 2D array
x = np.linspace(0,1,lenX)
y = np.linspace(0,1,lenY)
X, Y = np.meshgrid(x, y)     # Create a grid
Z1 = labels.view(lenX,lenY).cpu()
Z2 = pred.view(lenX,lenY).cpu()

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(121)
ax2 = fig.add_subplot(122)

# Plot the surface
surface1 = ax.imshow(Z1)
surface2 = ax2.imshow(Z2)

# Add a color bar for reference
fig.colorbar(surface1)
fig.colorbar(surface2)

# Label axes
ax.set_xlabel('Y-axis')
ax.set_ylabel('X-axis')

# Show the plot
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

# Plot the surface
surface1 = ax.imshow(np.abs(Z1-Z2))

# Add a color bar for reference
fig.colorbar(surface1)

# Label axes
ax.set_xlabel('Y-axis')
ax.set_ylabel('X-axis')

# Show the plot
plt.show()

# %%
ax1 = np.linspace(0,1,lenX)
plt.plot(ax1, Z1[int(lenX/2),:], label="Exact")
plt.plot(ax1, Z2[int(lenX/2),:],'.--r', label="Prediction")
plt.xlabel("y (m)")
plt.ylabel("p(x)")
plt.legend()

# %%
ax1 = np.linspace(0,1,lenX)
plt.plot(ax1, Z1[:,int(lenX/2)], label="Exact")
plt.plot(ax1, Z2[:,int(lenX/2)],'.--r', label="Prediction")
plt.xlabel("x (m)")
plt.ylabel("p(x)")
plt.legend()

# %%
plt.plot(Z1[:,-1])
plt.plot(Z2[:,-1])
